# %% [markdown]
# ### Q1. Explain the concept of R-squared in linear regression models. How is it calculated, and what does it represent?

# %% [markdown]
#  R-squared is a statistical measure that represents the goodness of fit of a regression model. The value of R-square lies between 0 to 1. Where we get R-square equals 1 when the model perfectly fits the data and there is no difference between the predicted value and actual value.  However, we get R-square equals 0 when the model does not predict any variability in the model and it does not learn any relationship between the dependent and independent variables.

# %% [markdown]
# ### Formulae:
# ![image.png](attachment:e1f4211e-2279-4832-8e4e-7947cfb51702.png)
#
# SSRes  - sum of Squares Residuals or Error ,
# SStotal - Sum of Squared Total

# %% [markdown]
# ### Q2. Define adjusted R-squared and explain how it differs from the regular R-squared.

# %% [markdown]
# ##### Adjusted R-Squared is an updated version of R-squared which takes account of the number of independent variables while calculating R-squared. The main problem with R-squared is that the R-Square value always increases with an increase in independent variables irrespective of the fact that where the independent variable is contributing to the model or not. This leads to the model having high variance if the model has a lot of independent variables.

# %% [markdown]
# ### Q3. When is it more appropriate to use adjusted R-squared?

# %% [markdown]
# Adjusted R-squared is typically used when comparing regression models with different numbers of predictors or independent variables. The regular R-squared (coefficient of determination) measures the proportion of the variance in the dependent variable that is explained by the independent variables in the model. However, R-squared has a tendency to increase as more predictors are added to the model, even if those predictors do not significantly improve the model's fit.

# %% [markdown]
# #### Q4. What are RMSE, MSE, and MAE in the context of regression analysis? How are these metrics calculated, and what do they represent?

# %% [markdown]
# ### Mean Squared Error(MSE):
# Mean Squared Error represents the average of the squared difference between the original and predicted values in the data set. It measures the variance of the residuals.
# ![image.png](attachment:96e5ee3b-13c7-431c-a605-a7b597b60ad1.png)
# ### Mean Absolute Error(MAE):
# The Mean absolute error represents the average of the absolute difference between the actual and predicted values in the dataset. It measures the average of the residuals in the dataset.
# ![image.png](attachment:f24b1453-8f32-4ec4-835b-ffb47ccb2cd6.png)
# ### Root Mean Squared Error (RMSE) :
# Root Mean Squared Error is the square root of Mean Squared error. It measures the standard deviation of residuals.
# ![image.png](attachment:5dc79a5f-d3c5-4f5f-ae6c-d09171cbaf82.png)

# %% [markdown]
# ### Q5. Discuss the advantages and disadvantages of using RMSE, MSE, and MAE as evaluation metrics in regression analysis.

# %% [markdown]
# #### Mean Squared Error (MSE):
#
# Advantages:
# Penalizes larger errors more heavily than smaller errors due to squaring.
# Differentiable, making it suitable for optimization algorithms.
# It has one local and one global minima.
# Disadvantages:
# Sensitive to outliers since the errors are squared.
# It is not in the same unit.
#
# #### Root Mean Squared Error (RMSE):
#
# Advantages:
# Shares advantages with MSE but provides a metric in the same unit as the target variable, making it more interpretable.
# Sensitive to large errors but expressed in the original unit.
#
# Disadvantages:
# Still sensitive to outliers due to the square root operation.
# May not be suitable for datasets with a skewed distribution or a significant number of outliers.
#
# #### Mean Absolute Error (MAE):
#
# Advantages:
# It will be in same unit.
# Robust to outliers.
#
# Disadvantages:
# Convergence usaully takes time but optimization is complex.
# Time consuming.

# %% [markdown]
# ### Q6. Explain the concept of Lasso regularization. How does it differ from Ridge regularization,and when is
# it more appropriate to use?

# %% [markdown]
# ### Lasso Regression:
# It is used for Feature selection.
# In dataset if there is an low correlation need to remove the particular feature , i.e use Lasso (L. In Ridge (L2) Coefficient will be zero at some point.1)

# %% [markdown]
# ### Q7. How do regularized linear models help to prevent overfitting in machine learning? Provide an example to illustrate.

# %% [markdown]
# With the help of Ridge Regression(L2) we can prevent the overfitting in machine learning. We are penalizing the cost function.
# #### Example :
# For example, let’s consider a linear regression model that predicts the price of a house based on its square footage, number of bedrooms, and number of bathrooms. If we train this model on a small dataset, it may fit the training data too closely and overfit. To prevent overfitting, we can use L2 regularization by adding a penalty term to the cost function of the linear regression.

# %% [markdown]
# #### Q8. Discuss the limitations of regularized linear models and explain why they may not always be the best choice for regression analysis.

# %% [markdown]
# #### Limitation of Regression Analysis:
# If the relationship between the input features and the target variable is non-linear, then regularized linear models may not be the best choice for regression analysis.
#
# In regularized linear models can be computationally expensive to train, especially when dealing with large datasets.

# %% [markdown]
# #### Q9. You are comparing the performance of two regression models using different evaluation metrics.
# Model A has an RMSE of 10, while Model B has an MAE of 8. Which model would you choose as the bette
# performer, and why? Are there any limitations to your choice of metric?

# %% [markdown]
# Since the MAE of Model B is lower than the RMSE of Model A, we can conclude that Model B is the better performer. However, it is important to note that the choice of metric depends on the specific problem and the nature of the data. For example, if the data contains many outliers, the RMSE may be a better choice

# %% [markdown]
# #### Q10. You are comparing the performance of two regularized linear models using different types of regularization. Model A uses Ridge regularization with a regularization parameter of 0.1, while Model B uses Lasso regularization with a regularization parameter of 0.5. Which model would you choose as the better performer, and why? Are there any trade-offs or limitations to your choice of regularization method?

# %% [markdown]
# In your case, Model A uses Ridge regularization with a regularization parameter of 0.1, while Model B uses Lasso regularization with a regularization parameter of 0.5. The choice of regularization method depends on the data and the problem at hand. If you have many features with high correlation and you need to take away the useless features, then Lasso is the better solution. On the other hand, if the number of features is greater than the number of observations and many features have multicollinearity, Ridge regularization is a better solution
